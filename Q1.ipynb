# %%
import cv2
from google.colab.patches import cv2_imshow
image = cv2.imread('/content/Sky-Blue-Colored-Car-Wallpaper-for-Download.jpg')
if image is None:
 print("Error: Could not load image")
else:
 print("Image loaded successfully")
cv2_imshow( image)
# Out:
# Image loaded successfully
# <PIL.Image.Image image mode=RGB size=585x472>

# %%
gray_image= cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=585x472>

# %%
gray_image
# Out:
# array([[152, 152, 152, ..., 125, 125, 125],
#        [151, 153, 152, ..., 127, 126, 126],
#        [153, 153, 153, ..., 126, 126, 126],
#        ...,
#        [144, 147, 144, ..., 154, 153, 150],
#        [141, 144, 145, ..., 153, 153, 150],
#        [145, 143, 142, ..., 153, 154, 150]], dtype=uint8)

# %%
image
# Out:
# array([[[189, 160, 123],
#         [189, 160, 123],
#         [189, 160, 123],
#         ...,
#         [166, 131,  97],
#         [166, 131,  97],
#         [166, 131,  97]],
#
#        [[188, 159, 122],
#         [190, 161, 124],
#         [189, 160, 123],
#         ...,
#         [168, 133,  99],
#         [167, 132,  98],
#         [167, 132,  98]],
#
#        [[190, 161, 124],
#         [190, 161, 124],
#         [190, 161, 124],
#         ...,
#         [167, 132,  98],
#         [167, 132,  98],
#         [167, 132,  98]],
#
#        ...,
#
#        [[125, 144, 152],
#         [128, 147, 155],
#         [125, 144, 151],
#         ...,
#         [135, 154, 162],
#         [132, 153, 161],
#         [131, 150, 158]],
#
#        [[122, 141, 149],
#         [125, 144, 152],
#         [127, 143, 155],
#         ...,
#         [134, 153, 161],
#         [134, 153, 161],
#         [131, 150, 158]],
#
#        [[126, 145, 153],
#         [124, 143, 151],
#         [124, 141, 150],
#         ...,
#         [134, 153, 161],
#         [135, 154, 162],
#         [131, 150, 158]]], dtype=uint8)

# %%
cv2.imwrite('gray_image.jpg', gray_image)
cv2.imwrite('color_image.jpg', image)
# Out:
# True
